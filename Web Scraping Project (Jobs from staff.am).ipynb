# %% [markdown]
# ## The aim of this project to extract data (advertised jobs) from the website (staff.am).

# %%
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages')

# %%
import requests

# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# #### The following function takes the url of website as an argument, accesses the website and gets the content. Afterwards, due to the BeautifulSoup function, the content then contains only HTML/valid website tags, from which the data about the job titles, company names, deadlines and locations are extracted.
#
# The function returns a list containing dictionaries of the details mentioned above.

# %%
def func_(url):
    response = requests.get(url)
    content = response.content
    soup = BeautifulSoup(content,"html.parser")
    names = soup.find_all("p",attrs={"class": "font_bold"})
    list_df=[]
    for i in range(len(names)-1):
        dict_df={}
        dict_df['Name'] = soup.find_all("p",attrs={"class": "font_bold"})[i].text.strip()
        dict_df['Company Name'] = soup.find_all("p",attrs={"class": "job_list_company_title"})[i].text.strip()
        dict_df['Deadline'] = soup.find_all("span",attrs={"class": "formatted_date"})[i].text.strip()
        dict_df['Location'] = soup.find_all("p",attrs={"class": "job_location"})[i].text.strip()
        list_df.append(dict_df)
    return list_df

# %% [markdown]
# For example, the jobs on the first page will be presented in the list1.

# %%
page1 = 'https://staff.am/en/jobs?JobsFilter%5Bkey_word%5D=&JobsFilter%5Bjob_candidate_level%5D=&JobsFilter%5Bcategory%5D=&JobsFilter%5Bjob_type%5D=&JobsFilter%5Bjob_term%5D=&JobsFilter%5Bjob_city%5D=&JobsFilter%5Bsort_by%5D=0&page=1&per-page=100'

# %%
list1 = func_(page1)

# %%
list1
# Out:
# [{'Name': 'System Administrator',
#   'Company Name': 'Praemium RA LLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Java Web Developer (Full Stack)',
#   'Company Name': 'Praemium RA LLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Full Stack .Net Developer',
#   'Company Name': 'Praemium RA LLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid C# / .NET developer',
#   'Company Name': 'VECTO',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'SEO Specialist at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Ասպիրանտուրա',
#   'Company Name': 'Հայաստանում ֆրանսիական համալսարան/ French University in Armenia (UFAR)',
#   'Deadline': '03 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid-Senior React.js / React Native Developer',
#   'Company Name': 'VECTO',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sr. Software Engineer, Front-End - ServicePro',
#   'Company Name': 'ServiceTitan',
#   'Deadline': '11 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid Magento Developer',
#   'Company Name': 'VECTO',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid QA Engineer',
#   'Company Name': 'VECTO',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior MacOS Engineer',
#   'Company Name': 'DISQO',
#   'Deadline': '21 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Գույնավոր քարերի մշակող',
#   'Company Name': 'ADM Diamonds LLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Abovyan'},
#  {'Name': 'Sales Manager',
#   'Company Name': 'inOne',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior React Developer',
#   'Company Name': 'RedKiteLLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Ֆիրմայի ներկայացուցիչ',
#   'Company Name': 'Bacon Product LLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Nurse-Coordinator',
#   'Company Name': 'American University of Armenia Fund',
#   'Deadline': '17 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Առաքիչ',
#   'Company Name': 'Atenk Ltd',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Շուկայի զարգացման պատասխանատու',
#   'Company Name': 'Atenk Ltd',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Առաքիչ',
#   'Company Name': 'Atenk Ltd',
#   'Deadline': '31 July 2021',
#   'Location': 'Stepanakert'},
#  {'Name': 'Senior PHP developer (Symfony/Laravel)',
#   'Company Name': 'RedKiteLLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sr. Java Programmer',
#   'Company Name': 'iHost',
#   'Deadline': '11 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior QA Automation Engineer',
#   'Company Name': 'Polixis',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Export Manager',
#   'Company Name': '«ԷՍԷՌ ՖՈՒԴ» ՍՊԸ',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'PRODUCT MANAGER',
#   'Company Name': 'Pharm Etalon LLC',
#   'Deadline': '10 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'UX Engineer (Strong Mid/Senior)',
#   'Company Name': 'HelpSystems Armenia',
#   'Deadline': '12 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Marketing Assistant',
#   'Company Name': 'Smooshop LLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Support Agent – German Language (Mixed shifts)',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Logistics and distribution manager',
#   'Company Name': 'MLN Pharm',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Support Agent – Turkish Language (Mixed shifts)',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '17 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Seller-Consultant / Aparan',
#   'Company Name': 'Mobile Centre',
#   'Deadline': '07 August 2021',
#   'Location': 'Aparan'},
#  {'Name': 'Customer Support Agent –English/Russian Languages (Mixed shifts)',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '17 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Graphic Designer',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '16 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid-level C# Developer',
#   'Company Name': 'Altacode',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'locksmith',
#   'Company Name': 'Daroink',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Junior/Mid Database Developer',
#   'Company Name': 'ՀԱՅԷԿՈՆՈՄԲԱՆԿ ԲԲԸ',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Junior/Mid software engineer',
#   'Company Name': 'ՀԱՅԷԿՈՆՈՄԲԱՆԿ ԲԲԸ',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Հաշվետար',
#   'Company Name': '360° ՇԻՆԲԱԶԱ',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Medical Representative',
#   'Company Name': 'Pharm Etalon LLC',
#   'Deadline': '10 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Գնումների /տենդեր/ մասնագետ',
#   'Company Name': 'Ռաֆ-Օջախ ՍՊԸ',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Ոսկերիչ-մասնագետ, ք. Երևան',
#   'Company Name': 'VTB Bank (Armenia)',
#   'Deadline': '01 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Wordpress developer',
#   'Company Name': 'Inexxus',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Տեղագրական Գեոդեզիստ',
#   'Company Name': 'AAB Construction',
#   'Deadline': '19 August 2021',
#   'Location': 'Alaverdi'},
#  {'Name': 'Bookkeeper/Հաշվետար',
#   'Company Name': 'Vardanants CIM',
#   'Deadline': '06 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Middle Laravel Developer',
#   'Company Name': 'M&D Systems LLC',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Experienced Project Manager',
#   'Company Name': 'Devolon Armenia',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Product Intelligence Analyst',
#   'Company Name': 'ServiceTitan',
#   'Deadline': '11 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sales Consultant',
#   'Company Name': 'SUPO LLC',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Product Designer',
#   'Company Name': 'SuperAnnotate',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Associate Product Manager',
#   'Company Name': 'SuperAnnotate',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Administrative Assistant',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'PPC Specialist',
#   'Company Name': 'SuperAnnotate',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Growth Marketer',
#   'Company Name': 'SuperAnnotate',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'UI/UX designer',
#   'Company Name': 'Fast Shift LLC',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Back end engineer',
#   'Company Name': 'Buymie',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Դրամային մենեջեր/Գանձապահ',
#   'Company Name': 'Պրեմիեր Ֆուդս ՍՊԸ',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Սուպերվիզոր',
#   'Company Name': 'Առաքելություն Հայաստան ԲՀԿ',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Սոցիալական աշխատող',
#   'Company Name': 'Առաքելություն Հայաստան ԲՀԿ',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Influencer Marketing and PR Specialist',
#   'Company Name': 'Woomler Engineering',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Head of Marketing',
#   'Company Name': 'Baklachoff Collection',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Experienced Node.js Developer',
#   'Company Name': 'Simply Technologies',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Վերլուծաբան',
#   'Company Name': 'Alfa-Pharm CJSC',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'React Native Developer',
#   'Company Name': 'Simply Technologies',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Branch manager',
#   'Company Name': 'ID Bank CJSC',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'QA Engineer',
#   'Company Name': 'Buymie',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Talent Acquisition Specialist',
#   'Company Name': 'ArctX LLC',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Junior Risk Manager at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Civil draftsman',
#   'Company Name': 'Atenk Ltd',
#   'Deadline': '10 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Frontend Developer Angular (React or Vue)',
#   'Company Name': 'Sparkers Data Company',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Data Analyst at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Junior Analytics Specialist at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Illustrator at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Motion Graphic Designer at VBet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'CRM Analyst at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Full-Stack web developer',
#   'Company Name': 'vvsoft',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'CRM Specialist at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Copywriter at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Administrative Assistant',
#   'Company Name': 'ADTEK',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Commercial Director',
#   'Company Name': 'ArLeAM',
#   'Deadline': '02 August 2021',
#   'Location': 'Ashtarak'},
#  {'Name': 'Senior PHP Developer',
#   'Company Name': 'Devolon Armenia',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Support Analyst II /ICT Officer',
#   'Company Name': 'World Vision Armenia',
#   'Deadline': '01 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'IT Monitoring Specialist',
#   'Company Name': 'Digitain',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'QA Engineer (m/f/d) Tensor',
#   'Company Name': 'TeamViewer Armenia',
#   'Deadline': '10 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Հսկիչ վաճառողուհի-գանձապահ',
#   'Company Name': 'Brand Leader',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Java Developer',
#   'Company Name': 'Devolon Armenia',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Policy Specialist',
#   'Company Name': 'UNDP Armenia Office',
#   'Deadline': '02 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Product Marketing Manager at VBET',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Marketing Executive at Vivaro',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Online shop assistant',
#   'Company Name': '"ALEX RETAIL COMPANY" LLC',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Chief accountant',
#   'Company Name': 'Ծիրան Մարկետ ՍՊԸ',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Operator (Live Video Streaming)',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '02 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Managing Director, Civic Education / Chief of Party',
#   'Company Name': 'Teach For Armenia',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Payment Operations Specialist at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Civic Education Expert',
#   'Company Name': 'Teach For Armenia',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Human Resource Manager',
#   'Company Name': 'Զանգակ-97 ՍՊԸ',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Head, Youth Civic Engagement',
#   'Company Name': 'Teach For Armenia',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Software Engineer',
#   'Company Name': 'Hexact',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer success and sales specialist',
#   'Company Name': 'Hexact',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'BackEnd Developer',
#   'Company Name': 'Hexact',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'ReactJs Developer',
#   'Company Name': 'Hexact',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'}]

# %% [markdown]
# The following code gets the URLs of all the available pages on the website. Afterwards, for all the possible URLs, the func_ function is being executed and all the returned lists are joined to the main list.

# %%
i = 1
main_list = []
while True:
    page_url = 'https://staff.am/en/jobs?JobsFilter%5Bkey_word%5D=&JobsFilter%5Bjob_candidate_level%5D=&JobsFilter%5Bcategory%5D=&JobsFilter%5Bjob_type%5D=&JobsFilter%5Bjob_term%5D=&JobsFilter%5Bjob_city%5D=&JobsFilter%5Bsort_by%5D=0&page='+str(i)+'&per-page=100'
    list_dfs = func_(page_url)
    if list_dfs == []:
        break
    main_list.extend(list_dfs)
    i +=1

# %%
main_list
# Out:
# [{'Name': 'Ոսկու զոդում,հղկում,փայլեցում և 3D մոդելավորողներ',
#   'Company Name': 'ADM Diamonds LLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Abovyan'},
#  {'Name': 'Revenue Assurance Unit Supervisor',
#   'Company Name': 'Viva-MTS (MTS Armenia CJSC)',
#   'Deadline': '27 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'System Administrator',
#   'Company Name': 'Praemium RA LLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Java Web Developer (Full Stack)',
#   'Company Name': 'Praemium RA LLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Full Stack .Net Developer',
#   'Company Name': 'Praemium RA LLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid C# / .NET developer',
#   'Company Name': 'VECTO',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'SEO Specialist at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Ասպիրանտուրա',
#   'Company Name': 'Հայաստանում ֆրանսիական համալսարան/ French University in Armenia (UFAR)',
#   'Deadline': '03 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid-Senior React.js / React Native Developer',
#   'Company Name': 'VECTO',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sr. Software Engineer, Front-End - ServicePro',
#   'Company Name': 'ServiceTitan',
#   'Deadline': '11 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid Magento Developer',
#   'Company Name': 'VECTO',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid QA Engineer',
#   'Company Name': 'VECTO',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior MacOS Engineer',
#   'Company Name': 'DISQO',
#   'Deadline': '21 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Գույնավոր քարերի մշակող',
#   'Company Name': 'ADM Diamonds LLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Abovyan'},
#  {'Name': 'Sales Manager',
#   'Company Name': 'inOne',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior React Developer',
#   'Company Name': 'RedKiteLLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Ֆիրմայի ներկայացուցիչ',
#   'Company Name': 'Bacon Product LLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Nurse-Coordinator',
#   'Company Name': 'American University of Armenia Fund',
#   'Deadline': '17 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Առաքիչ',
#   'Company Name': 'Atenk Ltd',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Շուկայի զարգացման պատասխանատու',
#   'Company Name': 'Atenk Ltd',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Առաքիչ',
#   'Company Name': 'Atenk Ltd',
#   'Deadline': '31 July 2021',
#   'Location': 'Stepanakert'},
#  {'Name': 'Senior PHP developer (Symfony/Laravel)',
#   'Company Name': 'RedKiteLLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sr. Java Programmer',
#   'Company Name': 'iHost',
#   'Deadline': '11 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior QA Automation Engineer',
#   'Company Name': 'Polixis',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Export Manager',
#   'Company Name': '«ԷՍԷՌ ՖՈՒԴ» ՍՊԸ',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'PRODUCT MANAGER',
#   'Company Name': 'Pharm Etalon LLC',
#   'Deadline': '10 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'UX Engineer (Strong Mid/Senior)',
#   'Company Name': 'HelpSystems Armenia',
#   'Deadline': '12 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Marketing Assistant',
#   'Company Name': 'Smooshop LLC',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Support Agent – German Language (Mixed shifts)',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Logistics and distribution manager',
#   'Company Name': 'MLN Pharm',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Support Agent – Turkish Language (Mixed shifts)',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '17 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Seller-Consultant / Aparan',
#   'Company Name': 'Mobile Centre',
#   'Deadline': '07 August 2021',
#   'Location': 'Aparan'},
#  {'Name': 'Customer Support Agent –English/Russian Languages (Mixed shifts)',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '17 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Graphic Designer',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '16 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid-level C# Developer',
#   'Company Name': 'Altacode',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'locksmith',
#   'Company Name': 'Daroink',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Junior/Mid Database Developer',
#   'Company Name': 'ՀԱՅԷԿՈՆՈՄԲԱՆԿ ԲԲԸ',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Junior/Mid software engineer',
#   'Company Name': 'ՀԱՅԷԿՈՆՈՄԲԱՆԿ ԲԲԸ',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Հաշվետար',
#   'Company Name': '360° ՇԻՆԲԱԶԱ',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Medical Representative',
#   'Company Name': 'Pharm Etalon LLC',
#   'Deadline': '10 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Գնումների /տենդեր/ մասնագետ',
#   'Company Name': 'Ռաֆ-Օջախ ՍՊԸ',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Ոսկերիչ-մասնագետ, ք. Երևան',
#   'Company Name': 'VTB Bank (Armenia)',
#   'Deadline': '01 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Wordpress developer',
#   'Company Name': 'Inexxus',
#   'Deadline': '19 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Տեղագրական Գեոդեզիստ',
#   'Company Name': 'AAB Construction',
#   'Deadline': '19 August 2021',
#   'Location': 'Alaverdi'},
#  {'Name': 'Bookkeeper/Հաշվետար',
#   'Company Name': 'Vardanants CIM',
#   'Deadline': '06 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Middle Laravel Developer',
#   'Company Name': 'M&D Systems LLC',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Experienced Project Manager',
#   'Company Name': 'Devolon Armenia',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Product Intelligence Analyst',
#   'Company Name': 'ServiceTitan',
#   'Deadline': '11 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sales Consultant',
#   'Company Name': 'SUPO LLC',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Product Designer',
#   'Company Name': 'SuperAnnotate',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Associate Product Manager',
#   'Company Name': 'SuperAnnotate',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Administrative Assistant',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'PPC Specialist',
#   'Company Name': 'SuperAnnotate',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Growth Marketer',
#   'Company Name': 'SuperAnnotate',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'UI/UX designer',
#   'Company Name': 'Fast Shift LLC',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Back end engineer',
#   'Company Name': 'Buymie',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Դրամային մենեջեր/Գանձապահ',
#   'Company Name': 'Պրեմիեր Ֆուդս ՍՊԸ',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Սուպերվիզոր',
#   'Company Name': 'Առաքելություն Հայաստան ԲՀԿ',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Սոցիալական աշխատող',
#   'Company Name': 'Առաքելություն Հայաստան ԲՀԿ',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Influencer Marketing and PR Specialist',
#   'Company Name': 'Woomler Engineering',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Head of Marketing',
#   'Company Name': 'Baklachoff Collection',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Experienced Node.js Developer',
#   'Company Name': 'Simply Technologies',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Վերլուծաբան',
#   'Company Name': 'Alfa-Pharm CJSC',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'React Native Developer',
#   'Company Name': 'Simply Technologies',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Branch manager',
#   'Company Name': 'ID Bank CJSC',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'QA Engineer',
#   'Company Name': 'Buymie',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Talent Acquisition Specialist',
#   'Company Name': 'ArctX LLC',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Junior Risk Manager at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Civil draftsman',
#   'Company Name': 'Atenk Ltd',
#   'Deadline': '10 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Frontend Developer Angular (React or Vue)',
#   'Company Name': 'Sparkers Data Company',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Data Analyst at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Junior Analytics Specialist at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Illustrator at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Motion Graphic Designer at VBet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'CRM Analyst at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Full-Stack web developer',
#   'Company Name': 'vvsoft',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'CRM Specialist at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Copywriter at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Administrative Assistant',
#   'Company Name': 'ADTEK',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Commercial Director',
#   'Company Name': 'ArLeAM',
#   'Deadline': '02 August 2021',
#   'Location': 'Ashtarak'},
#  {'Name': 'Senior PHP Developer',
#   'Company Name': 'Devolon Armenia',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Support Analyst II /ICT Officer',
#   'Company Name': 'World Vision Armenia',
#   'Deadline': '01 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'IT Monitoring Specialist',
#   'Company Name': 'Digitain',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'QA Engineer (m/f/d) Tensor',
#   'Company Name': 'TeamViewer Armenia',
#   'Deadline': '10 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Հսկիչ վաճառողուհի-գանձապահ',
#   'Company Name': 'Brand Leader',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Java Developer',
#   'Company Name': 'Devolon Armenia',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Policy Specialist',
#   'Company Name': 'UNDP Armenia Office',
#   'Deadline': '02 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Product Marketing Manager at VBET',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Marketing Executive at Vivaro',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Online shop assistant',
#   'Company Name': '"ALEX RETAIL COMPANY" LLC',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Chief accountant',
#   'Company Name': 'Ծիրան Մարկետ ՍՊԸ',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Operator (Live Video Streaming)',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '02 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Managing Director, Civic Education / Chief of Party',
#   'Company Name': 'Teach For Armenia',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Payment Operations Specialist at Vbet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Civic Education Expert',
#   'Company Name': 'Teach For Armenia',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Human Resource Manager',
#   'Company Name': 'Զանգակ-97 ՍՊԸ',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Head, Youth Civic Engagement',
#   'Company Name': 'Teach For Armenia',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Software Engineer',
#   'Company Name': 'Hexact',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer success and sales specialist',
#   'Company Name': 'Hexact',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'ReactJs Developer',
#   'Company Name': 'Hexact',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Head, Civic Education',
#   'Company Name': 'Teach For Armenia',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'IT Specialist',
#   'Company Name': 'Art Lunch',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'User Acquisition Manager',
#   'Company Name': 'KINDDA',
#   'Deadline': '05 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Systems Analyst',
#   'Company Name': 'KINDDA',
#   'Deadline': '05 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Security Analyst',
#   'Company Name': 'KINDDA',
#   'Deadline': '05 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'SMM մասնագետ',
#   'Company Name': 'Զանգակ գրատուն ՍՊԸ',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Content Writer',
#   'Company Name': 'One Planet Studios Armenia',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'IT Project Manager',
#   'Company Name': 'One Planet Studios Armenia',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Quality Assurance (QA) Engineer',
#   'Company Name': 'Webb Fontaine Holding LLC',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Reconciliation officer',
#   'Company Name': 'Adjarabet.am',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Dart / Flutter developer',
#   'Company Name': '404LABS',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Operations Portfolio Manager',
#   'Company Name': 'Adjarabet.am',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Angular Developer',
#   'Company Name': '404LABS',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Node.js/NestJS developer',
#   'Company Name': '404LABS',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Accountants',
#   'Company Name': 'Mikshin',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Frontend Engineer, Data Infrastructure (Angular)',
#   'Company Name': 'Picsart',
#   'Deadline': '18 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'PR & Communication Specialist',
#   'Company Name': 'InConcept Labs',
#   'Deadline': '17 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Python Developer',
#   'Company Name': 'inDATAside',
#   'Deadline': '17 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Consultant',
#   'Company Name': 'ID Bank CJSC',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Service Specialist',
#   'Company Name': 'ID Bank CJSC',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Client Manager',
#   'Company Name': 'ID Bank CJSC',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Data Analyst',
#   'Company Name': 'Plat.ai',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Graphic Designer',
#   'Company Name': 'Mobile Centre',
#   'Deadline': '16 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Chess teacher',
#   'Company Name': 'Հայաստանում Եվրոպական Վարժարան հիմնադրամ',
#   'Deadline': '16 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Military science teacher',
#   'Company Name': 'Հայաստանում Եվրոպական Վարժարան հիմնադրամ',
#   'Deadline': '05 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Seller-Consultant / Yerevan',
#   'Company Name': 'Mobile Centre',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Full-stack Software Engineer',
#   'Company Name': 'Synergy International Systems',
#   'Deadline': '16 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Software Engineer in Test',
#   'Company Name': 'Synergy International Systems',
#   'Deadline': '16 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Local Consultant on Baseline and Final Evaluation Study (Shirak Region)',
#   'Company Name': 'Armenian Association of Social Workers',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Local Consultant on Baseline and Final Evaluation Study (Lori Region)',
#   'Company Name': 'Armenian Association of Social Workers',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Local Consultant on Baseline and Final Evaluation Study (Ararat, Armavir, Kotayq Regions)',
#   'Company Name': 'Armenian Association of Social Workers',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Local Consultant on Baseline and Final Evaluation Study (data analyst)',
#   'Company Name': 'Armenian Association of Social Workers',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'IT Risk Manager',
#   'Company Name': 'VTB Bank (Armenia)',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Գանձապահ Upay ընկերությունում / ք. Էջմիածին /',
#   'Company Name': 'Ucom',
#   'Deadline': '15 August 2021',
#   'Location': 'Vagharshapat'},
#  {'Name': 'Հոգեբան',
#   'Company Name': 'Առաքելություն Հայաստան ԲՀԿ',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Պահեստապետի օգնական',
#   'Company Name': 'Atenk Ltd',
#   'Deadline': '31 July 2021',
#   'Location': 'Abovyan'},
#  {'Name': 'Խմբակավար',
#   'Company Name': 'Առաքելություն Հայաստան ԲՀԿ',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'խորհրդատու վաճառողուհի',
#   'Company Name': 'VS Boutique',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Իրավախորհրդատու',
#   'Company Name': 'Առաքելություն Հայաստան ԲՀԿ',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Partnership Specialist',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Finance officer',
#   'Company Name': 'Առաքելություն Հայաստան ԲՀԿ',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'B2B Account Manager (Spanish Speaking)',
#   'Company Name': 'Digitain',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Product Security Engineer',
#   'Company Name': '10Web',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Graphic Designer',
#   'Company Name': 'ARMENIA WINE FACTORY LLC',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Marketing specialist',
#   'Company Name': 'Atenk Ltd',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Info Desk and Registration Coordinator in Gyumri',
#   'Company Name': 'TUMO Center for Creative Technologies',
#   'Deadline': '15 August 2021',
#   'Location': 'Gyumri'},
#  {'Name': 'Analyst',
#   'Company Name': 'LMS LLC, Loan Management Services',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Outreach Specialist',
#   'Company Name': 'TUMO Center for Creative Technologies',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Head of HR at ArLeAM',
#   'Company Name': 'ArLeAM',
#   'Deadline': '30 July 2021',
#   'Location': 'Ashtarak'},
#  {'Name': '#IDream ծրագիր',
#   'Company Name': 'ID Bank CJSC',
#   'Deadline': '05 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'PERSONAL BANKER',
#   'Company Name': 'Byblos Bank Armenia cjsc',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Internal Control and Risk Manager',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Search Engine Optimization Specialist',
#   'Company Name': 'IFCMARKETS.CORP.',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Manager',
#   'Company Name': 'Coffee House Company',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Home visit specialist',
#   'Company Name': 'LMS LLC, Loan Management Services',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Debt collection specialist',
#   'Company Name': 'LMS LLC, Loan Management Services',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Node.js developer',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '02 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Angular 2+',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '02 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'QA Automation Engineer',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '02 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'React.js Developer',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '02 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'C++ Developer',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '02 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Գործավար',
#   'Company Name': '«ՌՌՌ» ՀԱՆՔԱՅԻՆ ՋՐԵՐԻ ԳՈՐԾԱՐԱՆ ՓԲԸ (ԲՋՆԻ, ՆՈՅ)',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'PHP Developer',
#   'Company Name': 'Haysell',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'C# Developer',
#   'Company Name': 'Հայկական Ծրագրեր ՍՊԸ (Armsoft)',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Project Manager',
#   'Company Name': 'Տնտեսական Հետազոտությունների և Զարգացման Աջակցության կենտրոն',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Expert Analyst',
#   'Company Name': 'Տնտեսական Հետազոտությունների և Զարգացման Աջակցության կենտրոն',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Վարկային գործակալ՝ «Հրազդան» մասնաճյուղում',
#   'Company Name': 'Fast Credit Capital UCO CJSC',
#   'Deadline': '30 July 2021',
#   'Location': 'Hrazdan'},
#  {'Name': 'International Sales Manager',
#   'Company Name': 'HNet LLC',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior QA Automation Engineer (mobile)',
#   'Company Name': 'KINDDA',
#   'Deadline': '26 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior QA Automation Engineer (backend)',
#   'Company Name': 'KINDDA',
#   'Deadline': '26 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Database Administrator',
#   'Company Name': 'KINDDA',
#   'Deadline': '26 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Վաճառքի խորհրդատու Peter Benjamin&Co խանութ-սրահում',
#   'Company Name': '<<Յուվելոն>> ՍՊԸ PETER BENJAMIN&Co',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Saleswoman/salesman',
#   'Company Name': 'Atenk Ltd',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'P&C Business Partner, Armenia',
#   'Company Name': 'JTI ARMENIA CJSC',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Internal Auditor',
#   'Company Name': 'Evocabank',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Automation Team Lead',
#   'Company Name': 'Fifth LLC',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Test Automation Tech Lead',
#   'Company Name': 'Krisp',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Web Developer – ReactJS',
#   'Company Name': 'Optym Armenia',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Վարորդ / Ադմինիստրատիվ օգնական',
#   'Company Name': 'Ֆրիվեյ Ֆայնանս ՓԲԸ',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Java Engineer',
#   'Company Name': 'Optym Armenia',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior accountant',
#   'Company Name': 'Ֆրիվեյ Ֆայնանս ՓԲԸ',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Financial analyst with the knowledge of Italian',
#   'Company Name': 'cognaize cjsc',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Design engineer',
#   'Company Name': 'Arides LLC',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Receptionist',
#   'Company Name': 'Digitain',
#   'Deadline': '10 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Software Engineer (iOS) / iOS Developer (Remote)',
#   'Company Name': 'Appmediaco',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Service Manager',
#   'Company Name': 'IMEX GROUP',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'JavaScript Engineer, Data Infrastructure',
#   'Company Name': 'Picsart',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Business Development Manager & Sales',
#   'Company Name': 'DoublBee',
#   'Deadline': '15 August 2021',
#   'Location': 'Los Angeles'},
#  {'Name': 'Kolba Lab Lead',
#   'Company Name': 'UNDP Armenia Office',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sales Executive',
#   'Company Name': 'Jellyfish Yerevan',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Procurement specialist',
#   'Company Name': 'Locator CJSC',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'UI/UX Designer',
#   'Company Name': 'Dasaran Ed-Tech Company',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Software Engineer',
#   'Company Name': 'Viva-MTS (MTS Armenia CJSC)',
#   'Deadline': '23 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Junior Back-End Developer',
#   'Company Name': 'Dasaran Ed-Tech Company',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Infrastructure Delivery Services Specialist',
#   'Company Name': 'HSBC Bank Armenia CJSC',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Support Specialist with Focus on Chat (m/f/d)',
#   'Company Name': 'TeamViewer Armenia',
#   'Deadline': '03 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'iOS Developer',
#   'Company Name': 'Atomic S LLC',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Head of Business Continuity & Incident Management and Protective Security',
#   'Company Name': 'HSBC Bank Armenia CJSC',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Support Specialist - Bilingual English and Spanish (m/f/d)',
#   'Company Name': 'TeamViewer Armenia',
#   'Deadline': '01 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'IT Service Desk Administrator (m/f/d)',
#   'Company Name': 'TeamViewer Armenia',
#   'Deadline': '25 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid FPGA QA engineer (Vanadzor branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Vanadzor'},
#  {'Name': 'Junior FPGA Logical Verification engine (Vanadzor branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Vanadzor'},
#  {'Name': 'Lead/Senior Digital Design engineer (Vanadzor branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Vanadzor'},
#  {'Name': 'Senior FPGA Logical Verification Engineer (Vanadzor branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Vanadzor'},
#  {'Name': 'Senior Engineer for FPGA Development (Vanadzor branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Vanadzor'},
#  {'Name': 'Junior Engineer for FPGA Development (Vanadzor branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Vanadzor'},
#  {'Name': 'Mid/Junior Digital Design engineer (Vanadzor branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Vanadzor'},
#  {'Name': 'Junior FPGA QA Engineer (Vanadzor brannch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Vanadzor'},
#  {'Name': 'Forex Brokerage Specialist',
#   'Company Name': 'Equiti AM',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Online shopping specialist',
#   'Company Name': 'ՍՊՍ ՍԻԳԱՐՈՆ ՍՊԸ',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Experienced UI/UX designer',
#   'Company Name': 'ZEVIT LLC',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Վերստուգող',
#   'Company Name': 'ԿՐԵԴՈ ՖԻՆԱՆՍ ՈՒՎԿ ՓԲԸ',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Contact Center Hero',
#   'Company Name': 'Ginosi Apartels and Hotels',
#   'Deadline': '15 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Incident Manager',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Beauty and Sales Consultant',
#   'Company Name': 'Nairian CJSC',
#   'Deadline': '02 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Learning Coach in Gyumri',
#   'Company Name': 'TUMO Center for Creative Technologies',
#   'Deadline': '12 August 2021',
#   'Location': 'Gyumri'},
#  {'Name': 'Child Interactions Specialist',
#   'Company Name': 'Expper Technologies',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Հիփոթեքային վարկավորման կենտրոնի սրահի ադմինիստրատոր, ք. Երևան',
#   'Company Name': 'VTB Bank (Armenia)',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Executive Assistant/Office Manager',
#   'Company Name': 'Expper Technologies',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sales Development Representative',
#   'Company Name': 'Expper Technologies',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Marketing Specialist',
#   'Company Name': 'Expper Technologies',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Engineering Technician',
#   'Company Name': 'Expper Technologies',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Front End Software Engineer',
#   'Company Name': 'Talkdesk',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Ֆինանսական խորհրդատու',
#   'Company Name': 'Ardshinbank',
#   'Deadline': '21 July 2021',
#   'Location': 'Stepanavan'},
#  {'Name': 'Senior Electrical Engineer',
#   'Company Name': 'Expper Technologies',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Վարկային մասնագետ',
#   'Company Name': 'Ardshinbank',
#   'Deadline': '25 July 2021',
#   'Location': 'Martuni (Artsakh)'},
#  {'Name': 'Senior SEO Specialist',
#   'Company Name': 'ՋՈՅՆԹՈՒՀԱՅՐ',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Golang Developer (Remote)',
#   'Company Name': 'KINDDA',
#   'Deadline': '27 July 2021',
#   'Location': 'Remote'},
#  {'Name': 'Senior Golang Developer',
#   'Company Name': 'KINDDA',
#   'Deadline': '27 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior iOS Developer (Remote)',
#   'Company Name': 'KINDDA',
#   'Deadline': '27 July 2021',
#   'Location': 'Remote'},
#  {'Name': 'Senior iOS Developer',
#   'Company Name': 'KINDDA',
#   'Deadline': '27 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Node.js Developer (Remote)',
#   'Company Name': 'KINDDA',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Node.js Developer',
#   'Company Name': 'KINDDA',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Android Developer',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Backend Engineer, Search Engine (Node.js)',
#   'Company Name': 'Picsart',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Office Manager',
#   'Company Name': 'ProDigi Digital Agency',
#   'Deadline': '08 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Backend Engineer, Search Engine (Node.js)',
#   'Company Name': 'Picsart',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Android Developer',
#   'Company Name': 'Bootech CJSC',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Embedded Systems Engineer',
#   'Company Name': 'Expper Technologies',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Graduate Recruitment Manager',
#   'Company Name': 'Teach For Armenia',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Կրթական ծրագրերի համակարգող',
#   'Company Name': '818 Consulting',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Գլխավոր հաշվապահ (ՎՌ Արմենիան Ֆրութ ՍՊԸ)',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Ameria CJSC, Assistant to the Chief Financial Officer',
#   'Company Name': 'Ameria CJSC',
#   'Deadline': '27 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Program Officer (Executive Branch)',
#   'Company Name': 'International Republican Institute',
#   'Deadline': '25 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Office manager',
#   'Company Name': 'MLN Pharm',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Market analyst',
#   'Company Name': 'Sparkers Data Company',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Jeweler',
#   'Company Name': 'ID Bank CJSC',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'CALL CENTER OPERATOR',
#   'Company Name': 'Flash',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Technical Support Specialist',
#   'Company Name': 'Locator CJSC',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Graphic / Web designer',
#   'Company Name': 'ONEX LLC',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mobile App Developer (iOS or Android)',
#   'Company Name': 'ONEX LLC',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Head of Human Resources Department at VBet',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Procurement Specialist (Construction Projects)',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Procurement Manager',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Accounting operator',
#   'Company Name': 'Nayiri Food',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Android Developer',
#   'Company Name': 'Marktguru',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Հաճախորդների Սպասարկման Գերմանախոս Մասնագետ',
#   'Company Name': 'CMX Solutions',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Խնդրահարույց ակտիվների հետ աշխատանքի մասնագետ',
#   'Company Name': 'VTB Bank (Armenia)',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'IT Support Specialist',
#   'Company Name': 'Exinity Group',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'engineer constructor',
#   'Company Name': 'Gapex LLC',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Marketing & Business Development Manager',
#   'Company Name': 'Cretrix',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Front Desk Agent',
#   'Company Name': 'Ibis Yerevan Center',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Լոգիստիկայի մասնագետ',
#   'Company Name': 'Ռաֆ-Օջախ ՍՊԸ',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Ներմուծման և արտահանման մասնագետ',
#   'Company Name': 'Ռաֆ-Օջախ ՍՊԸ',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Javascript/Front-End Developer',
#   'Company Name': 'AIKODA LLC',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Marketing Communication Specialist',
#   'Company Name': 'MAROG Creative Agency',
#   'Deadline': '23 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Digital Marketing Specialist',
#   'Company Name': 'Art Lunch',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Recruiter',
#   'Company Name': 'ՍՊՍ ՍԻԳԱՐՈՆ ՍՊԸ',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Content Writer',
#   'Company Name': '"ALEX RETAIL COMPANY" LLC',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Commercial Sales Manager',
#   'Company Name': 'Grand Revolt',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Public Relations Officer',
#   'Company Name': 'My Step Charitable Foundation',
#   'Deadline': '25 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Web Developer',
#   'Company Name': 'MentorcliQ',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Talent Recruiter',
#   'Company Name': 'TUMO Center for Creative Technologies',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid Java Developer',
#   'Company Name': 'Ultralabs AM',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Business Analyst',
#   'Company Name': 'KINDDA',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Cashier',
#   'Company Name': '"ALEX RETAIL COMPANY" LLC',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Data Analyst',
#   'Company Name': 'Krisp',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Judicial Acts Enforcement Assurance Junior Lawyer',
#   'Company Name': 'Viva-MTS (MTS Armenia CJSC)',
#   'Deadline': '23 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'PHP Developer',
#   'Company Name': 'CertiPro Solutions',
#   'Deadline': '14 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Import specialist',
#   'Company Name': 'Atenk Ltd',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Վաճառքի մենեջեր',
#   'Company Name': 'Foody',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Gaming Operations Specialist (day/night shift)',
#   'Company Name': 'Technamin',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Manual QA Engineer',
#   'Company Name': 'Synergy International Systems',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Consultant for implementation of Trainings for Social Workers',
#   'Company Name': 'Armenian Association of Social Workers',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'ՄՌԿ (Մարդկային ռեսուրսների կառավարման) մասնագետ',
#   'Company Name': 'Magnus',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid/Senior .Net Developer',
#   'Company Name': 'Loy & Hutz',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Web Developer',
#   'Company Name': 'Loy & Hutz',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Head of Marketing',
#   'Company Name': 'AAB Construction',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'IT Security Senior specialist',
#   'Company Name': 'Viva-MTS (MTS Armenia CJSC)',
#   'Deadline': '22 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Ինժեներ-տեխնոլոգ',
#   'Company Name': '818 Consulting',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Digital Marketing Specialist',
#   'Company Name': 'Armenian Code Academy',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior FPGA Logical Verification Engineer (Gyumri branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Gyumri'},
#  {'Name': 'Junior FPGA Logical Verification engineer (Gyumri branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Gyumri'},
#  {'Name': 'Mid FPGA QA engineer (Gyumri branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Gyumri'},
#  {'Name': 'Junior Engineer for FPGA Development (Gyumri branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Gyumri'},
#  {'Name': 'SQA Engineer',
#   'Company Name': 'Veritas Technologies Armenia',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Junior FPGA QA Engineer (Gyumri branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Gyumri'},
#  {'Name': 'Mid Android Developer',
#   'Company Name': 'Cypress',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'QA engineer',
#   'Company Name': 'EpygiArm LLC',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Կորպորատիվ հաճախորդների սպասարկման մասնագետ',
#   'Company Name': 'ID Bank CJSC',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Call Centre, Information group specialist',
#   'Company Name': 'ID Bank CJSC',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Programmer',
#   'Company Name': 'ACRA CREDIT REPORTING CJSC',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Call Center Specialist (evening and night shift)',
#   'Company Name': 'ID Bank CJSC',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Տնօրենի օգնական վաճառքների գծով',
#   'Company Name': 'Էյչ Վի Էյ Սի Գրուպ ՍՊԸ',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Legal Counsel',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Մարքեթինգային հետազոտությունների և հաշվետվությունների պրակտիկանտ',
#   'Company Name': 'ID Bank CJSC',
#   'Deadline': '21 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Accountant',
#   'Company Name': 'ԹԻ ԷՄ ԷԼ ՔՈՆՍԱԼԹԻՆԳ ՍՊԸ',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Content Manager',
#   'Company Name': 'Imea Systems',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Օդափոխության համակարգերի մոնտաժող մասնագետ',
#   'Company Name': 'Էյչ Վի Էյ Սի Գրուպ ՍՊԸ',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Brand Manager',
#   'Company Name': 'Մեգա Ֆուդ ՍՊԸ',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Lead/Senior Digital Design engineer (Gyumri branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Gyumri'},
#  {'Name': 'IT PROJECT MANAGER',
#   'Company Name': 'Concept Studio',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Human Resources Assistant',
#   'Company Name': 'SOLARA',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Node.js Developer',
#   'Company Name': 'Technamin',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Տնօրենի օգնական — Քարտուղարուհի',
#   'Company Name': 'CROWE & ASATRYANS LLC',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid/Junior Digital Design engineer (Gyumri branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Gyumri'},
#  {'Name': 'Accountant',
#   'Company Name': 'Evocabank',
#   'Deadline': '01 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid React Developer',
#   'Company Name': 'Essential',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Digital Marketer',
#   'Company Name': 'The Business Rover',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Engineer for FPGA Development (Gyumri branch)',
#   'Company Name': 'Instigate Semiconductor',
#   'Deadline': '13 August 2021',
#   'Location': 'Gyumri'},
#  {'Name': '3D designer',
#   'Company Name': 'Մավենտ ֆասադ սիստեմ ՍՊԸ',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'QA Automation Engineer',
#   'Company Name': 'Essential',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Project / Sales manager',
#   'Company Name': 'Մավենտ ֆասադ սիստեմ ՍՊԸ',
#   'Deadline': '12 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Գանձապահ՝ «Սեբաստիա» մասնաճյուղում՝ 19։00-02։00 աշխատաժամանակով',
#   'Company Name': 'Fast Credit Capital UCO CJSC',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Համակարգչային օպերատոր',
#   'Company Name': 'Tempus Group',
#   'Deadline': '12 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Client Solutions Engineer',
#   'Company Name': 'OMD LLC',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Executive Assistant',
#   'Company Name': 'SOLARA',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Internship',
#   'Company Name': 'Inecobank CJCS',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Backend Engineer, Data Infrastructure (Java)',
#   'Company Name': 'Picsart',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Job opportunities in regions',
#   'Company Name': 'Inecobank CJCS',
#   'Deadline': '08 August 2021',
#   'Location': 'Armenia (All cities)'},
#  {'Name': 'Experienced DB Developer',
#   'Company Name': 'VOLO',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Կոմերցիոն մասնագետ',
#   'Company Name': 'Basic Corporation',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'LAWYER',
#   'Company Name': 'Tax Law',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sales Manager',
#   'Company Name': 'MEDIA SYSTEMS',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Backend Engineer, Search Engine (Java)',
#   'Company Name': 'Picsart',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Backend Engineer, Search Engine (Java)',
#   'Company Name': 'Picsart',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Warehouse administrator',
#   'Company Name': 'Philip Morris Armenia LLC',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Head of Recruitment',
#   'Company Name': 'Teach For Armenia',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Վաճառքի գործակալ-մենեջեր',
#   'Company Name': 'Ավալոն ՍՎ ՍՊԸ',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Հաշվապահ/հաշվետար',
#   'Company Name': 'Art Lunch',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Internship for Young Engineers',
#   'Company Name': 'AAB Construction',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Quality, Training and Communications specialist',
#   'Company Name': 'Digitain',
#   'Deadline': '23 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Courier driver',
#   'Company Name': 'ԳԱՎԱ ԳՐՈՒՊ ՍՊԸ',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sales Consultant',
#   'Company Name': 'Semarco',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'SMM specialist',
#   'Company Name': 'Web Foundation',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Կորպորատիվ հաճախորդների հետ աշխատանքի մենեջեր, ք․ Դիլիջան',
#   'Company Name': 'VTB Bank (Armenia)',
#   'Deadline': '31 July 2021',
#   'Location': 'Dilijan'},
#  {'Name': '.NET Developer',
#   'Company Name': 'EpygiArm LLC',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Վաճառող խորհրդատու',
#   'Company Name': '360° ՇԻՆԲԱԶԱ',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Electron.js Engineer',
#   'Company Name': 'Krisp',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'TELLER',
#   'Company Name': 'Byblos Bank Armenia cjsc',
#   'Deadline': '31 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'R&D Engineer II, Windows',
#   'Company Name': 'Krisp',
#   'Deadline': '13 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Educational Programs Lead',
#   'Company Name': 'FAST',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Talent Acquisition Specialist',
#   'Company Name': 'Evolution',
#   'Deadline': '12 August 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Tech recruiter',
#   'Company Name': 'NoyMed LLC',
#   'Deadline': '12 August 2021',
#   'Location': 'Yerevan'},
# ...
#   'Location': 'Yerevan'},
#  {'Name': 'Front end Developer',
#   'Company Name': 'IYC technologies',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Տեխնիկական սպասարկման օպերատոր',
#   'Company Name': 'Alfa-Pharm CJSC',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid/Senior UI/UX Designer',
#   'Company Name': 'InConcept Labs',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Գլխավոր Վարկային Մասնագետ',
#   'Company Name': '«Միկրո Կապիտալ Հայաստան» ՈւՎԿ ՓԲԸ',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Copywriter',
#   'Company Name': 'TCF Armenia',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Full Stack Web Developer (remote)',
#   'Company Name': 'Sygnoos',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Service specialist OVS',
#   'Company Name': 'IMEX GROUP',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid React Native Developer',
#   'Company Name': 'Aparg',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Tech Recruiter',
#   'Company Name': 'MentorcliQ',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Աճի մասնագետ',
#   'Company Name': 'gg',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Հաշվապահ',
#   'Company Name': 'Անդակո ՍՊԸ',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Junior Test Automation Engineer (Java)',
#   'Company Name': 'EPAM Systems',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Service Specialist',
#   'Company Name': 'Մեյլ Էքսպրես ՍՊԸ',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Primary school teacher',
#   'Company Name': 'CIS Armenia International School',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid level PHP Developer',
#   'Company Name': 'AOByte',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Data Feed Administrator',
#   'Company Name': 'Praemium RA LLC',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Digital Marketing Specialist',
#   'Company Name': 'Yerevan Mall',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'HR Specialist',
#   'Company Name': 'Exterior Group LLC',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'iOS Developer',
#   'Company Name': 'ARM-BOLDMIND',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Campaign Coordinator (Marketing Executive)',
#   'Company Name': 'Sportion AM',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Java Backend Developer',
#   'Company Name': 'ARM-BOLDMIND',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior PHP Developer',
#   'Company Name': 'AOByte',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Support Representative ( Turkish speaking)',
#   'Company Name': 'BSG IT Consultancy',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'sales consultant',
#   'Company Name': 'Rouge Beaute LLC',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Project Manager',
#   'Company Name': 'Sportion AM',
#   'Deadline': '30 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Acumatica Developer',
#   'Company Name': 'BTS',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Kino Park Cashier',
#   'Company Name': 'Yerevan Mall',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Digital Marketing Intern',
#   'Company Name': 'Fimetech LLC',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Analyst',
#   'Company Name': 'Granatus Ventures',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Call Center Specialist',
#   'Company Name': 'Converse Bank',
#   'Deadline': '20 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Security worker',
#   'Company Name': 'IMEX GROUP',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Rental Agent for Hertz Armenia',
#   'Company Name': 'HERTZ TRAVELEX LLC',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Software Engineer ( iOS )',
#   'Company Name': 'Imagenomic',
#   'Deadline': '25 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'HR Manager',
#   'Company Name': 'Brainstorm Technologies',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Software Engineer (C/C++)',
#   'Company Name': 'Imagenomic',
#   'Deadline': '25 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Սրահի մենեջերի օգնական',
#   'Company Name': 'Ashley Homestore',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Product Manager',
#   'Company Name': 'Webb Fontaine Holding LLC',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Главный инженер',
#   'Company Name': 'EKRA Caucasus',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Security officer',
#   'Company Name': 'Atenk Ltd',
#   'Deadline': '27 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid React Developer',
#   'Company Name': 'ZOOM GRAPHICS',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Administrative assistant / Office manager',
#   'Company Name': 'ԱԿՎԱՏՈՒՍ ՍՊԸ',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Account Manager',
#   'Company Name': 'Publicis Hepta LLC',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'React.js Developer',
#   'Company Name': 'Weflex',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Node.js Developer',
#   'Company Name': 'Weflex',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Angular Developer',
#   'Company Name': 'Iguan Systems LLC',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Node JS Developer',
#   'Company Name': 'Iguan Systems LLC',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Head of Mechanical Workshop',
#   'Company Name': 'AeroDynamics',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Technical department engineer',
#   'Company Name': 'Family Network',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Պահեստի աշխատակից',
#   'Company Name': 'Globbing',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Teaching Associate | Part-time',
#   'Company Name': 'Webb Fontaine Holding LLC',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'UI/UX Designer',
#   'Company Name': 'Webb Fontaine Holding LLC',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customs Broker Assistant',
#   'Company Name': 'Globbing',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Logistics Specialist',
#   'Company Name': 'Coolina',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Internal Control and Risk Management Analyst',
#   'Company Name': 'ARGE BUSINESS LLC',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'UI/UX Designer',
#   'Company Name': 'Ucom',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'ՏԵԽՆԻԿԱԿԱՆ ԱՋԱԿՑՈՒԹՅԱՆ ՄԱՍՆԱԳԵՏ',
#   'Company Name': 'Հայ-Թեք Գեթվեյ ՍՊԸ հ/մ',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sales Operations Analyst',
#   'Company Name': 'SADA Global Delivery Center',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sales Compensation Analyst',
#   'Company Name': 'SADA Global Delivery Center',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Billing Operations Analyst',
#   'Company Name': 'SADA Global Delivery Center',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Staff Accountant',
#   'Company Name': 'SADA Global Delivery Center',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Accounts Payable Analyst',
#   'Company Name': 'SADA Global Delivery Center',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sales Manager',
#   'Company Name': 'MSS Boost',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Office Coordinator Lead',
#   'Company Name': 'Evolution',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Accountant',
#   'Company Name': 'ԷՖ ԹԻ ՔՆՍԱԼԹԻՆԳ ՍՊԸ',
#   'Deadline': '27 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Technical Support Engineer',
#   'Company Name': 'Veritas Technologies Armenia',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior .Net Developer',
#   'Company Name': 'Veritas Technologies Armenia',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'DevOps Engineer',
#   'Company Name': 'Veritas Technologies Armenia',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Գնումների մասնագետ',
#   'Company Name': 'Messier 53 Hotel Yerevan',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Program Manager',
#   'Company Name': 'Veritas Technologies Armenia',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Marketing Manager',
#   'Company Name': 'Messier 53 Hotel Yerevan',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Ֆինանսական խորհրդատու, ք. Երևան',
#   'Company Name': 'Converse Bank',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Android Developer',
#   'Company Name': 'Menu Group UK ltd',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sales Manager',
#   'Company Name': 'Messier 53 Hotel Yerevan',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'QA engineer',
#   'Company Name': 'Menu Group UK ltd',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid QA Engineer',
#   'Company Name': 'Benivo',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Վաճառքի մենեջեր',
#   'Company Name': 'Մեգնա ՍՊԸ',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Խորհրդատու-վաճառողուհի',
#   'Company Name': 'Castero',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'UI/UX designer',
#   'Company Name': 'Telecom Armenia CJSC',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Junior Specialist for EY Tax practice',
#   'Company Name': 'Ernst and Young CJSC (EY)',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Project engineer',
#   'Company Name': 'ASEDL LLC',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Support Agent – Persian Language (Mixed shifts)',
#   'Company Name': 'SoftConstruct',
#   'Deadline': '20 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Product Manager',
#   'Company Name': 'Ucom',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sales Consultant Part Time',
#   'Company Name': 'Cole Haan',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Customer Technical Support',
#   'Company Name': 'Sparkers Data Company',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Պահակ',
#   'Company Name': 'EKRA Caucasus',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Accountant-Operator',
#   'Company Name': 'IMEX GROUP',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Support manager',
#   'Company Name': 'AMarkets',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Frontend JavaScript Developer (Mid/Senior)',
#   'Company Name': 'Hex Division LLC',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'BackEnd JavaScript Developer (Mid/Senior)',
#   'Company Name': 'Hex Division LLC',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'DevOps Engineer',
#   'Company Name': 'Hex Division LLC',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Call Center Specialist',
#   'Company Name': 'Telecom Armenia CJSC',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Experienced Angular Developer',
#   'Company Name': 'VOLO',
#   'Deadline': '25 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'DevOps Engineer',
#   'Company Name': 'VOLO',
#   'Deadline': '25 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Experienced QA Manual/Automation Engineer',
#   'Company Name': 'VOLO',
#   'Deadline': '25 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Automation QA Engineer',
#   'Company Name': 'VOLO',
#   'Deadline': '25 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Android Developer',
#   'Company Name': 'VOLO',
#   'Deadline': '25 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior iOS Developer',
#   'Company Name': 'VOLO',
#   'Deadline': '25 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior .NET Developer',
#   'Company Name': 'VOLO',
#   'Deadline': '25 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Experienced .NET Developer',
#   'Company Name': 'VOLO',
#   'Deadline': '25 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Java Software Engineer',
#   'Company Name': 'Webb Fontaine Holding LLC',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'AIR TICKET SPECIALIST',
#   'Company Name': 'Liberty Incentive LLC',
#   'Deadline': '23 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Human Resources Manager',
#   'Company Name': 'Messier 53 Hotel Yerevan',
#   'Deadline': '21 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'PHP Developer',
#   'Company Name': 'ZOOM GRAPHICS',
#   'Deadline': '29 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Active Sales Specialist',
#   'Company Name': 'ASEDL LLC',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Data Engineer',
#   'Company Name': 'Krisp',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Backend Engineer',
#   'Company Name': 'Krisp',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior ML Engineer, Personalized Noise Cancellation',
#   'Company Name': 'Krisp',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Вакансия Курьер Glovo в Ереване (They/She/He)',
#   'Company Name': 'GLOVO',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Country Lead (They/She/He)',
#   'Company Name': 'GLOVO',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Content Analyst (They/She/He)',
#   'Company Name': 'GLOVO',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Export Manager',
#   'Company Name': 'Exterior Group LLC',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Courier Operations Specialist (They/She/He)',
#   'Company Name': 'GLOVO',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Sales Specialist (They/She/He)',
#   'Company Name': 'GLOVO',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Node.js Developer',
#   'Company Name': 'Hexact',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Senior Node.js Developer',
#   'Company Name': 'Hexact',
#   'Deadline': '24 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Teller',
#   'Company Name': 'Ameriabank CJSC',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'FULL STACK DEVELOPER (ASP.NET)',
#   'Company Name': 'Personas Recruiting',
#   'Deadline': '28 July 2021',
#   'Location': 'London'},
#  {'Name': 'Executive Assistant to Director',
#   'Company Name': 'Webb Fontaine Holding LLC',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'SENIOR JAVA DEVELOPER',
#   'Company Name': 'Personas Recruiting',
#   'Deadline': '28 July 2021',
#   'Location': 'London'},
#  {'Name': 'General Manager',
#   'Company Name': 'Webb Fontaine Holding LLC',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Accountant',
#   'Company Name': 'AAB Construction',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Mid Android Developer',
#   'Company Name': 'Menu Group UK ltd',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Talent Acquisition Specialist',
#   'Company Name': 'AAB Construction',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  {'Name': 'Procurement Specialist',
#   'Company Name': 'AAB Construction',
#   'Deadline': '28 July 2021',
#   'Location': 'Yerevan'},
#  ...]

# %%
print('The website currently contains ' + str(len(main_list)) + ' job advertisments.')
# Out:
# The website currently contains 1266 job advertisments.

# %%
import pandas as pd
df = pandas.DataFrame(main_list)

# %%
df.head()
# Out:
#                                                 Name  \
# 0  Ոսկու զոդում,հղկում,փայլեցում և 3D մոդելավորողներ
# 1                  Revenue Assurance Unit Supervisor
# 2                               System Administrator
# 3                    Java Web Developer (Full Stack)
# 4                          Full Stack .Net Developer
#
#                   Company Name        Deadline Location
# 0             ADM Diamonds LLC  19 August 2021  Abovyan
# 1  Viva-MTS (MTS Armenia CJSC)    27 July 2021  Yerevan
# 2              Praemium RA LLC  19 August 2021  Yerevan
# 3              Praemium RA LLC  19 August 2021  Yerevan
# 4              Praemium RA LLC  19 August 2021  Yerevan

# %%
df['Deadline'] = pd.to_datetime(df['Deadline'], format='%d %B %Y')

# %%
df.sort_values('Deadline')
# Out:
#                                                    Name         Company Name  \
# 1265  Senior Backend Engineer, Enterprise (Node.js/J...              Picsart
# 740                .NET Software Engineer - Mid 3 Level  HelpSystems Armenia
# 739                .NET Software Engineer - Mid 1 Level  HelpSystems Armenia
# 738                                Senior .NET Engineer  HelpSystems Armenia
# 721            Գլխավոր հաշվապահ (ՎՌ Արմենիան Ֆրութ ՍՊԸ)        SoftConstruct
# ...                                                 ...                  ...
# 40                          Գնումների /տենդեր/ մասնագետ         Ռաֆ-Օջախ ՍՊԸ
# 42                                  Wordpress developer              Inexxus
# 43                                 Տեղագրական Գեոդեզիստ     AAB Construction
# 16                                Ֆիրմայի ներկայացուցիչ    Bacon Product LLC
# 0     Ոսկու զոդում,հղկում,փայլեցում և 3D մոդելավորողներ     ADM Diamonds LLC
#
#        Deadline  Location
# 1265 2021-07-20   Yerevan
# 740  2021-07-20   Yerevan
# 739  2021-07-20   Yerevan
# 738  2021-07-20   Yerevan
# 721  2021-07-20   Yerevan
# ...         ...       ...
# 40   2021-08-19   Yerevan
# 42   2021-08-19   Yerevan
# 43   2021-08-19  Alaverdi
# 16   2021-08-19   Yerevan
# 0    2021-08-19   Abovyan
#
# [1266 rows x 4 columns]

# %% [markdown]
# ### The top locations.

# %%
a = df.groupby('Location').count()

# %%
a.sort_values('Name', ascending=False)
# Out:
#                       Name  Company Name  Deadline
# Location
# Yerevan               1194          1194      1194
# Gyumri                  12            12        12
# Vanadzor                10            10        10
# Dilijan                  5             5         5
# Remote                   5             5         5
# Abovyan                  5             5         5
# Armenia (All cities)     3             3         3
# Hrazdan                  3             3         3
# Ashtarak                 2             2         2
# Vedi                     2             2         2
# London                   2             2         2
# Los Angeles              2             2         2
# Vagharshapat             2             2         2
# Toronto                  2             2         2
# Armavir                  2             2         2
# Stepanakert              2             2         2
# Tashir                   1             1         1
# Yeghvard                 1             1         1
# Aparan                   1             1         1
# Tsaghkadzor              1             1         1
# Nagorno-Karabakh         1             1         1
# Stepanavan               1             1         1
# Berd                     1             1         1
# Masis                    1             1         1
# Martuni (Artsakh)        1             1         1
# Alaverdi                 1             1         1
# Ijevan                   1             1         1
# Artashat                 1             1         1
# Martuni                  1             1         1

# %% [markdown]
# ### The top 20 companies.

# %%
companies = df.groupby('Company Name').count()

# %%
companies.sort_values('Name', ascending=False).head(20)
# Out:
#                                        Name  Deadline  Location
# Company Name
# SoftConstruct                            53        53        53
# ArctX LLC                                30        30        30
# Atenk Ltd                                27        27        27
# EPAM Systems                             27        27        27
# KINDDA                                   21        21        21
# Synopsys Armenia                         20        20        20
# Digitain                                 19        19        19
# TUMO Center for Creative Technologies    19        19        19
# Webb Fontaine Holding LLC                19        19        19
# Instigate Semiconductor                  18        18        18
# IMEX GROUP                               17        17        17
# Ardshinbank                              16        16        16
# Adjarabet.am                             15        15        15
# Krisp                                    15        15        15
# ID Bank CJSC                             15        15        15
# ServiceTitan                             13        13        13
# Picsart                                  12        12        12
# SADA Global Delivery Center              12        12        12
# VOLO                                     11        11        11
# Ucom                                     11        11        11

# %%
df.to_csv("jobs.csv",index=False)

# %% [markdown]
# The data included in the project is presented on 20.07.21 at 16.00 pm.
